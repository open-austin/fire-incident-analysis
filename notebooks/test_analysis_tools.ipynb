# %% [markdown]
# ## Question 1:
# Function `parse_census_tracts` doesn't work?

# %%
incidents, pop_data, housing_data, age_data = load_data()
# Out:
# Loading data...
#   Structure fire incidents: 3,176
#   Incidents with tract data: 3,176 (100.0%)
#   Census tracts with population: 471
#   Census tracts with housing: 471
#   Census tracts with building age: 471

# %%
incidents.head()
# Out:
#    incident_number  calendaryear month                 incdate call_type  \
# 0         22000037          2022   Jan  01/01/2022 12:00:00 AM      Fire
# 1         22000085          2022   Jan  01/01/2022 12:00:00 AM      Fire
# 2         22000122          2022   Jan  01/01/2022 12:00:00 AM      Fire
# 3         22000252          2022   Jan  01/01/2022 12:00:00 AM      Fire
# 4         22000440          2022   Jan  01/01/2022 12:00:00 AM      Fire
#
#                   problem responsearea jurisdiction prioritydescription  \
# 0     BOX -Structure Fire      00-2306          AFD                  1F
# 1  BOXS - Still Box Alarm      00-1407          AFD                  1F
# 2    BOXL- Structure Fire      00-4104          AFD                  1F
# 3     BOX -Structure Fire      00-1709          AFD                  1F
# 4     BOX -Structure Fire      00-2306          AFD                  1F
#
#   council_district                location  longitude   latitude  \
# ...

# %%
incidents[['incident_number', 'census_tracts', 'tract_list']][incidents['tract_list'].apply(len) > 1].head()
# Out:
#      incident_number             census_tracts          tract_list
# 34          22003662          ['2.04', '2.03']        [2.04, 2.03]
# 54          22007278        ['23.24', '23.26']      [23.24, 23.26]
# 69          22009976            ['313', '319']          [313, 319]
# 85          22011294        ['13.08', '13.07']      [13.08, 13.07]
# 100         22012115  ['6.06', '6.05', '2.04']  [6.06, 6.05, 2.04]

# %%
import geopandas as gpd
tracts = gpd.read_file('../raw_data/tl_2023_48_tract.shp')
tracts.head()
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID               GEOIDFQ    NAME  \
# 0      48      157  674100  48157674100  1400000US48157674100    6741
# 1      48      157  674200  48157674200  1400000US48157674200    6742
# 2      48      441  013501  48441013501  1400000US48441013501  135.01
# 3      48      441  013602  48441013602  1400000US48441013602  136.02
# 4      48      441  013601  48441013601  1400000US48441013601  136.01
#
#               NAMELSAD  MTFCC FUNCSTAT      ALAND   AWATER     INTPTLAT  \
# 0    Census Tract 6741  G5020        S    4170615        0  +29.5791692
# 1    Census Tract 6742  G5020        S    5800266   189859  +29.5713421
# 2  Census Tract 135.01  G5020        S  866463520  4539887  +32.1806265
# 3  Census Tract 136.02  G5020        S  665184779   422010  +32.3991003
# 4  Census Tract 136.01  G5020        S   36492558        0  +32.4639334
#
#        INTPTLON                                           geometry
# ...

# %%
census_df = pd.read_csv("../raw_data/census_housing.csv", dtype={'tract': str})

# %%
census_df.head()
# Out:
#    Total  1-unit, detached  1-unit, attached  2 units  3-4 units  5-9 units  \
# 0   1339               471                47       31         41        187
# 1    915               217                56        0         63         79
# 2   1939               638                42       81        230        147
# 3   2854               401                56       49        427        168
# 4   1516               123                 0       62         15        105
#
#    10-19 units  20-49 units  50 or more units  Mobile home  Boat, RV, van  \
# 0          176           69               300           17              0
# 1           81           48               346           25              0
# 2          203          144               217          237              0
# 3         1068          203               394           88              0
# 4          156          161               152          742              0
#
# ...
